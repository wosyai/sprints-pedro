# %%
import ast
import re
import os

base_path = '/home/pedro/logic-test-main/sources/rpa/tim'
python_files = [f for f in os.listdir(base_path) if f.endswith('.py')]


print(python_files)
# Out:
# ['bases_diarias_sms_por_campanha.py', 'voice_interactions5.py', 'bases_diarias_abandono_fluxo_tim.py', 'bases_diarias_sms_por_campanha_completa_flash.py', 'flash_tim.py', 'web_interactions_metrics.py', 'voice_interactions12.py', 'voice_interactions9.py', 'bases_diarias_sms_por_campanha_flash.py', 'voice_interactions7.py', 'voice_interactions4.py', 'voice_interactions10.py', 'voice_interactions8.py', 'conexoes.py', 'ura.py', 'voice_interactions6.py', 'cruzarmento_ura.py', 'dividir_voice_interactions.py', 'voice_interactions13.py', 'voice_interactions11.py', 'bases_diarias_sms_por_campanha_completa.py', 'voice_interactions3.py', 'voice_interactions2.py']

# %%
def extract_sql_tables(content):
    inputs = set()  
    outputs = set() 
    
    sql_patterns = [
        r'self\.cur(?:_\d+)?\.execute\([rf]?[\'\"](.*?)[\'\"]\)',
        r'self\.cursor\.execute\([rf]?[\'\"](.*?)[\'\"]\)',
        r'\.execute\([rf]?[\'\"](.*?)[\'\"]\)'
    ]
    
    sql_commands = []
    for pattern in sql_patterns:
        matches = re.findall(pattern, content, re.DOTALL | re.IGNORECASE)
        sql_commands.extend(matches)
    
    for sql in sql_commands:
        sql_clean = re.sub(r'\s+', ' ', sql.strip())
        sql_clean = sql_clean.replace('{', '').replace('}', '')
        
        # INPUTS: FROM e JOIN (incluindo production schema)
        select_pattern = r'(?:FROM|JOIN)\s+(?:(?:public|production)\.)?([a-zA-Z_][a-zA-Z0-9_]*)'
        select_matches = re.findall(select_pattern, sql_clean, re.IGNORECASE)
        inputs.update(select_matches)
        
        # OUTPUTS: INSERT, UPDATE, DELETE (incluindo production schema)
        insert_pattern = r'INSERT\s+INTO\s+(?:(?:public|production)\.)?([a-zA-Z_][a-zA-Z0-9_]*)'
        insert_matches = re.findall(insert_pattern, sql_clean, re.IGNORECASE)
        outputs.update(insert_matches)
        
        update_pattern = r'UPDATE\s+(?:(?:public|production)\.)?([a-zA-Z_][a-zA-Z0-9_]*)'
        update_matches = re.findall(update_pattern, sql_clean, re.IGNORECASE)
        outputs.update(update_matches)
        
        delete_pattern = r'DELETE\s+FROM\s+(?:(?:public|production)\.)?([a-zA-Z_][a-zA-Z0-9_]*)'
        delete_matches = re.findall(delete_pattern, sql_clean, re.IGNORECASE)
        outputs.update(delete_matches)
    
    # Remover schemas que podem ter sido capturados incorretamente
    schemas_to_remove = {'production', 'public'}
    inputs = inputs - schemas_to_remove
    outputs = outputs - schemas_to_remove
    
    # Remover outputs dos inputs (DELETE FROM tabela não conta como input)
    inputs = inputs - outputs
    
    return list(inputs), list(outputs)

# %%
def extract_queries(content):
    sql_patterns = [
        r'self\.cur(?:_\d+)?\.execute\([rf]?[\'\"](.*?)[\'\"]\)',
        r'self\.cursor\.execute\([rf]?[\'\"](.*?)[\'\"]\)',
        r'\.execute\([rf]?[\'\"](.*?)[\'\"]\)'
    ]
    
    queries = []
    for pattern in sql_patterns:
        matches = re.findall(pattern, content, re.DOTALL | re.IGNORECASE)
        for match in matches:
            clean_query = re.sub(r'\s+', ' ', match.strip())
            clean_query = clean_query.replace('{', '').replace('}', '')
            queries.append(clean_query)
    
    return queries

def find_dependencies(content):
    dependencies = []
    if 'from conexoes import' in content:
        dependencies.append('conexoes.py')
    return dependencies

# %%
import json
results = {}

for file in python_files:
    file_path = os.path.join(base_path, file)
    with open(file_path, 'r') as f:
        content = f.read()
    
    inputs, outputs = extract_sql_tables(content)
    queries = extract_queries(content)
    deps = find_dependencies(content)
    
    results[file] = {
        "arquivo": file,
        "arquivo_de_dependencia": deps,
        "queries": queries,
        "tabelas": {
            "inputs": inputs,
            "outputs": outputs
        }
    }

print(json.dumps(results, indent=2, ensure_ascii=False))
# Out:
# {
#   "bases_diarias_sms_por_campanha.py": {
#     "arquivo": "bases_diarias_sms_por_campanha.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\" select c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' when c.id = 2 then '09 Informativo' when c.id = 63 then '07 Pagamento de fatura' else '' end \"MACRO_CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03 Pré > Controle' when c.id = 2 then '09.01 Regulatório / Obrigatório TIM' when c.id = 63 then '07.01 Meio de pagamento (ex-Parcerias)' else '' end \"CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03.02 Pré > Controle : SEM aparelho' when c.id = 2 then '09.01.02 Normativo : COM relação direta' when c.id = 63 then '07.01.05 Pagamento por outros meios (ex-Parcerias)' else '' end \"SUB_CATEGORIA\", count(se.id) as \"VOLUME_PUBLICO\", r.type as \"TIPO_MENSAGEM\" from production.sent_messages as se inner join production.rules r ON se.rule_id = r.id inner join production.campaigns c ON r.campaign_id = c.id where (se.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "\"\" select '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "DELETE FROM sms_por_campanha WHERE mes_referencia ='data_inicial'",
#       "\"\" select c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' when c.id = 2 then '09 Informativo' when c.id = 63 then '07 Pagamento de fatura' else '' end \"MACRO_CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03 Pré > Controle' when c.id = 2 then '09.01 Regulatório / Obrigatório TIM' when c.id = 63 then '07.01 Meio de pagamento (ex-Parcerias)' else '' end \"CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03.02 Pré > Controle : SEM aparelho' when c.id = 2 then '09.01.02 Normativo : COM relação direta' when c.id = 63 then '07.01.05 Pagamento por outros meios (ex-Parcerias)' else '' end \"SUB_CATEGORIA\", count(se.id) as \"VOLUME_PUBLICO\", r.type as \"TIPO_MENSAGEM\" from production.sent_messages as se inner join production.rules r ON se.rule_id = r.id inner join production.campaigns c ON r.campaign_id = c.id where (se.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "\"\" select '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "DELETE FROM sms_por_campanha WHERE mes_referencia ='data_inicial'"
#     ],
#     "tabelas": {
#       "inputs": [
#         "sent_messages",
#         "message_outbound",
#         "rules",
#         "campaigns"
#       ],
#       "outputs": [
#         "sms_por_campanha"
#       ]
#     }
#   },
#   "voice_interactions5.py": {
#     "arquivo": "voice_interactions5.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-05 00:00:00' and '2024-06-05 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-05 00:00:00' and '2024-06-05 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "bases_diarias_abandono_fluxo_tim.py": {
#     "arquivo": "bases_diarias_abandono_fluxo_tim.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where substring(pvi.phone, 13, 1) = 'i' and (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where substring(pvi.phone, 13, 1) = 'i' and (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where substring(pvi.phone, 13, 1) = 'i' and (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where substring(pvi.phone, 13, 1) = 'i' and (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where (pvi.created_at between 'data 00:00:00' and 'data 23:59:59"
#     ],
#     "tabelas": {
#       "inputs": [
#         "orders",
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "bases_diarias_sms_por_campanha_completa_flash.py": {
#     "arquivo": "bases_diarias_sms_por_campanha_completa_flash.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\" select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "DELETE FROM sms_por_campanha WHERE mes_referencia ='data_inicial'",
#       "\"\" select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "DELETE FROM sms_por_campanha WHERE mes_referencia ='data_inicial'"
#     ],
#     "tabelas": {
#       "inputs": [
#         "message_outbound"
#       ],
#       "outputs": [
#         "sms_por_campanha"
#       ]
#     }
#   },
#   "flash_tim.py": {
#     "arquivo": "flash_tim.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\" select count(id) as \"notification\", status, date_format(sent_at, \"%Y-%m-%d",
#       "DELETE FROM flash_tim WHERE date >='data 00:00:00'",
#       "\"\" select count(id) as \"notification\", status, date_format(sent_at, \"%Y-%m-%d",
#       "DELETE FROM flash_tim WHERE date >='data 00:00:00'"
#     ],
#     "tabelas": {
#       "inputs": [],
#       "outputs": [
#         "flash_tim"
#       ]
#     }
#   },
#   "web_interactions_metrics.py": {
#     "arquivo": "web_interactions_metrics.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select count(anonymous) as \"accesses\", count(distinct(anonymous)) as \"unique_accesses\", ga_to, \"to\", \"from\", ga_from, origin, host, created_at::date as \"created_at\" from public.web_interactions where host in ('suatimlive.com.br', 'timofertas.com', 'internetfibratim.com.br",
#       "DELETE FROM web_interactions_metrics WHERE created_at >='data 00:00:00'",
#       "\"\"select count(anonymous) as \"accesses\", count(distinct(anonymous)) as \"unique_accesses\", ga_to, \"to\", \"from\", ga_from, origin, host, created_at::date as \"created_at\" from public.web_interactions where host in ('suatimlive.com.br', 'timofertas.com', 'internetfibratim.com.br",
#       "DELETE FROM web_interactions_metrics WHERE created_at >='data 00:00:00'"
#     ],
#     "tabelas": {
#       "inputs": [
#         "web_interactions"
#       ],
#       "outputs": [
#         "web_interactions_metrics"
#       ]
#     }
#   },
#   "voice_interactions12.py": {
#     "arquivo": "voice_interactions12.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-13 00:00:00' and '2024-06-13 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-13 00:00:00' and '2024-06-13 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "voice_interactions9.py": {
#     "arquivo": "voice_interactions9.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-09 00:00:00' and '2024-06-09 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-09 00:00:00' and '2024-06-09 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "bases_diarias_sms_por_campanha_flash.py": {
#     "arquivo": "bases_diarias_sms_por_campanha_flash.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\" select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", mo.msisdn as \"NUM_TELEFONE\", 'SMS' as \"CANAL\", '' as \"EMAIL\", mo.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\", mo.sent_at as \"DATA_ENVIO\", mo.message as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from message_outbound as mo where (mo.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59",
#       "\"\" select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", mo.msisdn as \"NUM_TELEFONE\", 'SMS' as \"CANAL\", '' as \"EMAIL\", mo.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\", mo.sent_at as \"DATA_ENVIO\", mo.message as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from message_outbound as mo where (mo.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59"
#     ],
#     "tabelas": {
#       "inputs": [
#         "message_outbound"
#       ],
#       "outputs": []
#     }
#   },
#   "voice_interactions7.py": {
#     "arquivo": "voice_interactions7.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-07 00:00:00' and '2024-06-07 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-07 00:00:00' and '2024-06-07 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "voice_interactions4.py": {
#     "arquivo": "voice_interactions4.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-04 00:00:00' and '2024-06-04 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-04 00:00:00' and '2024-06-04 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "voice_interactions10.py": {
#     "arquivo": "voice_interactions10.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-10 00:00:00' and '2024-06-10 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-10 00:00:00' and '2024-06-10 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "voice_interactions8.py": {
#     "arquivo": "voice_interactions8.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-08 00:00:00' and '2024-06-08 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-08 00:00:00' and '2024-06-08 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "conexoes.py": {
#     "arquivo": "conexoes.py",
#     "arquivo_de_dependencia": [],
#     "queries": [],
#     "tabelas": {
#       "inputs": [],
#       "outputs": []
#     }
#   },
#   "ura.py": {
#     "arquivo": "ura.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-12-01 00:00:00' and '2024-12-10 23:59:59';\"\"",
#       "\"\"select distinct(msisdn) as \"phone\" from blacklists;\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-12-01 00:00:00' and '2024-12-10 23:59:59';\"\"",
#       "\"\"select distinct(msisdn) as \"phone\" from blacklists;\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "blacklists",
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "voice_interactions6.py": {
#     "arquivo": "voice_interactions6.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-06 00:00:00' and '2024-06-06 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-06 00:00:00' and '2024-06-06 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "cruzarmento_ura.py": {
#     "arquivo": "cruzarmento_ura.py",
#     "arquivo_de_dependencia": [],
#     "queries": [],
#     "tabelas": {
#       "inputs": [],
#       "outputs": []
#     }
#   },
#   "dividir_voice_interactions.py": {
#     "arquivo": "dividir_voice_interactions.py",
#     "arquivo_de_dependencia": [],
#     "queries": [],
#     "tabelas": {
#       "inputs": [],
#       "outputs": []
#     }
#   },
#   "voice_interactions13.py": {
#     "arquivo": "voice_interactions13.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-14 00:00:00' and '2024-06-14 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-14 00:00:00' and '2024-06-14 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "voice_interactions11.py": {
#     "arquivo": "voice_interactions11.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-12 00:00:00' and '2024-06-12 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-12 00:00:00' and '2024-06-12 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "bases_diarias_sms_por_campanha_completa.py": {
#     "arquivo": "bases_diarias_sms_por_campanha_completa.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", se.phone as \"NUM_TELEFONE\", r.type as \"CANAL\", '' as \"EMAIL\", se.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\",se.sent_at as \"DATA_ENVIO\", se.text as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from production.sent_messages as se inner join production.rules r on se.rule_id = r.id inner join production.campaigns c on r.campaign_id = c.id where (se.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59",
#       "\"\"select '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", mo.msisdn as \"NUM_TELEFONE\", 'SMS' as \"CANAL\", '' as \"EMAIL\", mo.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\", mo.sent_at as \"DATA_ENVIO\", mo.message as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59",
#       "\"\"select c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", se.phone as \"NUM_TELEFONE\", r.type as \"CANAL\", '' as \"EMAIL\", se.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\",se.sent_at as \"DATA_ENVIO\", se.text as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from production.sent_messages as se inner join production.rules r on se.rule_id = r.id inner join production.campaigns c on r.campaign_id = c.id where (se.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59",
#       "\"\"select '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", mo.msisdn as \"NUM_TELEFONE\", 'SMS' as \"CANAL\", '' as \"EMAIL\", mo.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\", mo.sent_at as \"DATA_ENVIO\", mo.message as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59"
#     ],
#     "tabelas": {
#       "inputs": [
#         "sent_messages",
#         "message_outbound",
#         "rules",
#         "campaigns"
#       ],
#       "outputs": []
#     }
#   },
#   "voice_interactions3.py": {
#     "arquivo": "voice_interactions3.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-03 00:00:00' and '2024-06-03 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-03 00:00:00' and '2024-06-03 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   },
#   "voice_interactions2.py": {
#     "arquivo": "voice_interactions2.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-01 00:00:00' and '2024-08-29 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-01 00:00:00' and '2024-08-29 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     }
#   }
# }

# %% [markdown]
# host = db
# database = schema
#
# cruzamento
#  e ver quais cada uma das tabelas ver quais sao o host e db
#  olhar pros outputs e ver quais scripts esta otratando do msm output
#
#  separar eles e tacar na llm e transformar em um union all.

# %%
def add_connection_mapping(results):
    # Ler conexoes.py
    with open(os.path.join(base_path, 'conexoes.py'), 'r') as f:
        conexoes_content = f.read()
    
    # Extrair host/database
    connection_pattern = r'class\s+(conexao[A-Za-z0-9_]+).*?host\s*=\s*[\'"]([^\'"]+)[\'"].*?database\s*=\s*[\'"]([^\'"]+)[\'"]'
    connections = re.findall(connection_pattern, conexoes_content, re.DOTALL)
    
    connection_map = {name: {'host': host, 'database': db} for name, host, db in connections}
    
    # Adicionar info aos resultados
    for file, data in results.items():
        if file != 'conexoes.py':
            file_path = os.path.join(base_path, file)
            with open(file_path, 'r') as f:
                content = f.read()
            
            used_conn = [conn for conn in connection_map.keys() if conn in content]
            data['connection_mapping'] = {
                conn: connection_map[conn] for conn in used_conn
            }
    
    return results

# %%
def find_shared_outputs(results):
    output_map = {}
    
    for file, data in results.items():
        outputs = data.get('tabelas', {}).get('outputs', [])
        for output in outputs:
            if output not in output_map:
                output_map[output] = []
            output_map[output].append({
                'file': file,
                'queries': [q for q in data.get('queries', []) if 'SELECT' in q.upper()]
            })
    
    # Retornar apenas outputs compartilhados
    return {k: v for k, v in output_map.items() if len(v) > 1}

# %%
# Seu código atual + adições
for file in python_files:
    file_path = os.path.join(base_path, file)
    with open(file_path, 'r') as f:
        content = f.read()
    
    inputs, outputs = extract_sql_tables(content)
    queries = extract_queries(content)
    deps = find_dependencies(content)
    
    results[file] = {
        "arquivo": file,
        "arquivo_de_dependencia": deps,
        "queries": queries,
        "tabelas": {
            "inputs": inputs,
            "outputs": outputs
        }
    }

# Enriquecer com informações de conexão
results = add_connection_mapping(results)

# Encontrar outputs compartilhados
shared_outputs = find_shared_outputs(results)

print("=== RESULTADOS ENRIQUECIDOS ===")
print(json.dumps(results, indent=2, ensure_ascii=False))

print("\n=== OUTPUTS COMPARTILHADOS ===")
for output, files in shared_outputs.items():
    print(f"\nTabela/Output: {output}")
    for file_info in files:
        print(f"  - Arquivo: {file_info['file']}")
        for query in file_info['queries'][:1]:  # Primeira query apenas
            print(f"    Query: {query[:100]}...")
# Out:
# === RESULTADOS ENRIQUECIDOS ===
# {
#   "bases_diarias_sms_por_campanha.py": {
#     "arquivo": "bases_diarias_sms_por_campanha.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\" select c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' when c.id = 2 then '09 Informativo' when c.id = 63 then '07 Pagamento de fatura' else '' end \"MACRO_CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03 Pré > Controle' when c.id = 2 then '09.01 Regulatório / Obrigatório TIM' when c.id = 63 then '07.01 Meio de pagamento (ex-Parcerias)' else '' end \"CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03.02 Pré > Controle : SEM aparelho' when c.id = 2 then '09.01.02 Normativo : COM relação direta' when c.id = 63 then '07.01.05 Pagamento por outros meios (ex-Parcerias)' else '' end \"SUB_CATEGORIA\", count(se.id) as \"VOLUME_PUBLICO\", r.type as \"TIPO_MENSAGEM\" from production.sent_messages as se inner join production.rules r ON se.rule_id = r.id inner join production.campaigns c ON r.campaign_id = c.id where (se.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "\"\" select '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "DELETE FROM sms_por_campanha WHERE mes_referencia ='data_inicial'",
#       "\"\" select c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' when c.id = 2 then '09 Informativo' when c.id = 63 then '07 Pagamento de fatura' else '' end \"MACRO_CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03 Pré > Controle' when c.id = 2 then '09.01 Regulatório / Obrigatório TIM' when c.id = 63 then '07.01 Meio de pagamento (ex-Parcerias)' else '' end \"CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03.02 Pré > Controle : SEM aparelho' when c.id = 2 then '09.01.02 Normativo : COM relação direta' when c.id = 63 then '07.01.05 Pagamento por outros meios (ex-Parcerias)' else '' end \"SUB_CATEGORIA\", count(se.id) as \"VOLUME_PUBLICO\", r.type as \"TIPO_MENSAGEM\" from production.sent_messages as se inner join production.rules r ON se.rule_id = r.id inner join production.campaigns c ON r.campaign_id = c.id where (se.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "\"\" select '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "DELETE FROM sms_por_campanha WHERE mes_referencia ='data_inicial'"
#     ],
#     "tabelas": {
#       "inputs": [
#         "sent_messages",
#         "message_outbound",
#         "rules",
#         "campaigns"
#       ],
#       "outputs": [
#         "sms_por_campanha"
#       ]
#     },
#     "connection_mapping": {
#       "conexaoMySQLLocalFlash": {
#         "host": "flash-sms.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "flashtim"
#       },
#       "conexaoMySQLLocalSMSCampanha": {
#         "host": "localhost",
#         "database": "sms_por_campanha"
#       },
#       "conexaoNotifier": {
#         "host": "notifier.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "postgres"
#       }
#     }
#   },
#   "voice_interactions5.py": {
#     "arquivo": "voice_interactions5.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-05 00:00:00' and '2024-06-05 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-05 00:00:00' and '2024-06-05 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "bases_diarias_abandono_fluxo_tim.py": {
#     "arquivo": "bases_diarias_abandono_fluxo_tim.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where substring(pvi.phone, 13, 1) = 'i' and (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where substring(pvi.phone, 13, 1) = 'i' and (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where substring(pvi.phone, 13, 1) = 'i' and (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where substring(pvi.phone, 13, 1) = 'i' and (pvi.created_at between 'data 00:00:00' and 'data 23:59:59",
#       "\"\"select distinct(pvi.phone) from public.voice_interactions as pvi left join public.orders as po on po.phone = pvi.phone where (pvi.created_at between 'data 00:00:00' and 'data 23:59:59"
#     ],
#     "tabelas": {
#       "inputs": [
#         "orders",
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       }
#     }
#   },
#   "bases_diarias_sms_por_campanha_completa_flash.py": {
#     "arquivo": "bases_diarias_sms_por_campanha_completa_flash.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\" select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "DELETE FROM sms_por_campanha WHERE mes_referencia ='data_inicial'",
#       "\"\" select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#       "DELETE FROM sms_por_campanha WHERE mes_referencia ='data_inicial'"
#     ],
#     "tabelas": {
#       "inputs": [
#         "message_outbound"
#       ],
#       "outputs": [
#         "sms_por_campanha"
#       ]
#     },
#     "connection_mapping": {
#       "conexaoMySQLLocalFlash": {
#         "host": "flash-sms.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "flashtim"
#       },
#       "conexaoMySQLLocalSMSCampanha": {
#         "host": "localhost",
#         "database": "sms_por_campanha"
#       },
#       "conexaoNotifier": {
#         "host": "notifier.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "postgres"
#       }
#     }
#   },
#   "flash_tim.py": {
#     "arquivo": "flash_tim.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\" select count(id) as \"notification\", status, date_format(sent_at, \"%Y-%m-%d",
#       "DELETE FROM flash_tim WHERE date >='data 00:00:00'",
#       "\"\" select count(id) as \"notification\", status, date_format(sent_at, \"%Y-%m-%d",
#       "DELETE FROM flash_tim WHERE date >='data 00:00:00'"
#     ],
#     "tabelas": {
#       "inputs": [],
#       "outputs": [
#         "flash_tim"
#       ]
#     },
#     "connection_mapping": {
#       "conexaoMySQLLocalFlashTim": {
#         "host": "localhost",
#         "database": "tim_go"
#       },
#       "conexaoMySQLLocalFlash": {
#         "host": "flash-sms.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "flashtim"
#       }
#     }
#   },
#   "web_interactions_metrics.py": {
#     "arquivo": "web_interactions_metrics.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select count(anonymous) as \"accesses\", count(distinct(anonymous)) as \"unique_accesses\", ga_to, \"to\", \"from\", ga_from, origin, host, created_at::date as \"created_at\" from public.web_interactions where host in ('suatimlive.com.br', 'timofertas.com', 'internetfibratim.com.br",
#       "DELETE FROM web_interactions_metrics WHERE created_at >='data 00:00:00'",
#       "\"\"select count(anonymous) as \"accesses\", count(distinct(anonymous)) as \"unique_accesses\", ga_to, \"to\", \"from\", ga_from, origin, host, created_at::date as \"created_at\" from public.web_interactions where host in ('suatimlive.com.br', 'timofertas.com', 'internetfibratim.com.br",
#       "DELETE FROM web_interactions_metrics WHERE created_at >='data 00:00:00'"
#     ],
#     "tabelas": {
#       "inputs": [
#         "web_interactions"
#       ],
#       "outputs": [
#         "web_interactions_metrics"
#       ]
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLLocalFlashTim": {
#         "host": "localhost",
#         "database": "tim_go"
#       },
#       "conexaoMySQLLocalFlash": {
#         "host": "flash-sms.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "flashtim"
#       }
#     }
#   },
#   "voice_interactions12.py": {
#     "arquivo": "voice_interactions12.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-13 00:00:00' and '2024-06-13 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-13 00:00:00' and '2024-06-13 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "voice_interactions9.py": {
#     "arquivo": "voice_interactions9.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-09 00:00:00' and '2024-06-09 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-09 00:00:00' and '2024-06-09 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "bases_diarias_sms_por_campanha_flash.py": {
#     "arquivo": "bases_diarias_sms_por_campanha_flash.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\" select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", mo.msisdn as \"NUM_TELEFONE\", 'SMS' as \"CANAL\", '' as \"EMAIL\", mo.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\", mo.sent_at as \"DATA_ENVIO\", mo.message as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from message_outbound as mo where (mo.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59",
#       "\"\" select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", mo.msisdn as \"NUM_TELEFONE\", 'SMS' as \"CANAL\", '' as \"EMAIL\", mo.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\", mo.sent_at as \"DATA_ENVIO\", mo.message as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from message_outbound as mo where (mo.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59"
#     ],
#     "tabelas": {
#       "inputs": [
#         "message_outbound"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoMySQLLocalFlash": {
#         "host": "flash-sms.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "flashtim"
#       },
#       "conexaoNotifier": {
#         "host": "notifier.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "postgres"
#       }
#     }
#   },
#   "voice_interactions7.py": {
#     "arquivo": "voice_interactions7.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-07 00:00:00' and '2024-06-07 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-07 00:00:00' and '2024-06-07 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "voice_interactions4.py": {
#     "arquivo": "voice_interactions4.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-04 00:00:00' and '2024-06-04 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-04 00:00:00' and '2024-06-04 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "voice_interactions10.py": {
#     "arquivo": "voice_interactions10.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-10 00:00:00' and '2024-06-10 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-10 00:00:00' and '2024-06-10 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "voice_interactions8.py": {
#     "arquivo": "voice_interactions8.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-08 00:00:00' and '2024-06-08 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-08 00:00:00' and '2024-06-08 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "conexoes.py": {
#     "arquivo": "conexoes.py",
#     "arquivo_de_dependencia": [],
#     "queries": [],
#     "tabelas": {
#       "inputs": [],
#       "outputs": []
#     }
#   },
#   "ura.py": {
#     "arquivo": "ura.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-12-01 00:00:00' and '2024-12-10 23:59:59';\"\"",
#       "\"\"select distinct(msisdn) as \"phone\" from blacklists;\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-12-01 00:00:00' and '2024-12-10 23:59:59';\"\"",
#       "\"\"select distinct(msisdn) as \"phone\" from blacklists;\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "blacklists",
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLLocalFlash": {
#         "host": "flash-sms.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "flashtim"
#       }
#     }
#   },
#   "voice_interactions6.py": {
#     "arquivo": "voice_interactions6.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-06 00:00:00' and '2024-06-06 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-06 00:00:00' and '2024-06-06 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "cruzarmento_ura.py": {
#     "arquivo": "cruzarmento_ura.py",
#     "arquivo_de_dependencia": [],
#     "queries": [],
#     "tabelas": {
#       "inputs": [],
#       "outputs": []
#     },
#     "connection_mapping": {}
#   },
#   "dividir_voice_interactions.py": {
#     "arquivo": "dividir_voice_interactions.py",
#     "arquivo_de_dependencia": [],
#     "queries": [],
#     "tabelas": {
#       "inputs": [],
#       "outputs": []
#     },
#     "connection_mapping": {}
#   },
#   "voice_interactions13.py": {
#     "arquivo": "voice_interactions13.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-14 00:00:00' and '2024-06-14 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-14 00:00:00' and '2024-06-14 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "voice_interactions11.py": {
#     "arquivo": "voice_interactions11.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-12 00:00:00' and '2024-06-12 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-12 00:00:00' and '2024-06-12 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "bases_diarias_sms_por_campanha_completa.py": {
#     "arquivo": "bases_diarias_sms_por_campanha_completa.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", se.phone as \"NUM_TELEFONE\", r.type as \"CANAL\", '' as \"EMAIL\", se.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\",se.sent_at as \"DATA_ENVIO\", se.text as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from production.sent_messages as se inner join production.rules r on se.rule_id = r.id inner join production.campaigns c on r.campaign_id = c.id where (se.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59",
#       "\"\"select '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", mo.msisdn as \"NUM_TELEFONE\", 'SMS' as \"CANAL\", '' as \"EMAIL\", mo.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\", mo.sent_at as \"DATA_ENVIO\", mo.message as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59",
#       "\"\"select c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", se.phone as \"NUM_TELEFONE\", r.type as \"CANAL\", '' as \"EMAIL\", se.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\",se.sent_at as \"DATA_ENVIO\", se.text as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from production.sent_messages as se inner join production.rules r on se.rule_id = r.id inner join production.campaigns c on r.campaign_id = c.id where (se.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59",
#       "\"\"select '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", mo.msisdn as \"NUM_TELEFONE\", 'SMS' as \"CANAL\", '' as \"EMAIL\", mo.sent_at as \"DATA_ENTREGA\", '' as \"DATA_ABERTURA\", '' as \"DATA_CLIQUE\", '' as \"DATA_CONVERSAO\", mo.sent_at as \"DATA_ENVIO\", mo.message as \"MENSAGEM\",'N' as \"FLAG_ENTREGUE\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at BETWEEN 'data 00:00:00' AND 'data 23:59:59"
#     ],
#     "tabelas": {
#       "inputs": [
#         "sent_messages",
#         "message_outbound",
#         "rules",
#         "campaigns"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoMySQLLocalFlash": {
#         "host": "flash-sms.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "flashtim"
#       },
#       "conexaoNotifier": {
#         "host": "notifier.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "postgres"
#       }
#     }
#   },
#   "voice_interactions3.py": {
#     "arquivo": "voice_interactions3.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-03 00:00:00' and '2024-06-03 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-03 00:00:00' and '2024-06-03 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   },
#   "voice_interactions2.py": {
#     "arquivo": "voice_interactions2.py",
#     "arquivo_de_dependencia": [
#       "conexoes.py"
#     ],
#     "queries": [
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-01 00:00:00' and '2024-08-29 23:59:59';\"\"",
#       "\"\"select distinct(phone) as \"phone\" from public.voice_interactions where created_at between '2024-06-01 00:00:00' and '2024-08-29 23:59:59';\"\""
#     ],
#     "tabelas": {
#       "inputs": [
#         "voice_interactions"
#       ],
#       "outputs": []
#     },
#     "connection_mapping": {
#       "conexaoTimGO": {
#         "host": "tim-general.clmst1oasags.us-east-1.rds.amazonaws.com",
#         "database": "timgo"
#       },
#       "conexaoMySQLCreditoEspecial": {
#         "host": "localhost",
#         "database": "credito"
#       }
#     }
#   }
# }
#
# === OUTPUTS COMPARTILHADOS ===
#
# Tabela/Output: sms_por_campanha
#   - Arquivo: bases_diarias_sms_por_campanha.py
#     Query: "" select c.id as "CODIGO_CAMPANHA", c.name as "NOME_CAMPANHA", 'data_inicial' as "MES_REFERENCIA", ...
#   - Arquivo: bases_diarias_sms_por_campanha_completa_flash.py
#     Query: "" select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campa...

# %%
def quick_shared_outputs(results):
    output_files = {}
    
    for file, data in results.items():
        outputs = data.get('tabelas', {}).get('outputs', [])
        for output in outputs:
            if output not in output_files:
                output_files[output] = []
            output_files[output].append(file)
    
    # Apenas outputs compartilhados
    shared = {k: v for k, v in output_files.items() if len(v) > 1}
    
    print("=== OUTPUTS COMPARTILHADOS ===")
    for output, files in shared.items():
        print(f"\n📊 Output: {output}")
        print(f"   Arquivos: {', '.join(files)}")
        
        for file in files:
            connections = results[file].get('connection_mapping', {})
            conn_info = list(connections.keys())
            print(f"   └─ {file}: {conn_info}")
    
    return shared

# %%
# Seu código atual + esta adição no final:
results = add_connection_mapping(results)

# Encontrar outputs compartilhados
shared_outputs = quick_shared_outputs(results)

# Para cada output compartilhado, extrair queries SELECT
print("\n=== CANDIDATOS PARA UNION ALL ===")
for output, files in shared_outputs.items():
    print(f"\n🎯 Target: {output}")
    
    for file in files:
        queries = results[file].get('queries', [])
        select_queries = [q for q in queries if 'SELECT' in q.upper()]
        
        if select_queries:
            print(f"\n📄 Arquivo: {file}")
            for i, query in enumerate(select_queries):
                clean_query = query.replace('""', '').strip()
                print(f"   Query {i+1}: {clean_query}")
# Out:
# === OUTPUTS COMPARTILHADOS ===
#
# 📊 Output: sms_por_campanha
#    Arquivos: bases_diarias_sms_por_campanha.py, bases_diarias_sms_por_campanha_completa_flash.py
#    └─ bases_diarias_sms_por_campanha.py: ['conexaoMySQLLocalFlash', 'conexaoMySQLLocalSMSCampanha', 'conexaoNotifier']
#    └─ bases_diarias_sms_por_campanha_completa_flash.py: ['conexaoMySQLLocalFlash', 'conexaoMySQLLocalSMSCampanha', 'conexaoNotifier']
#
# === CANDIDATOS PARA UNION ALL ===
#
# 🎯 Target: sms_por_campanha
#
# 📄 Arquivo: bases_diarias_sms_por_campanha.py
#    Query 1: select c.id as "CODIGO_CAMPANHA", c.name as "NOME_CAMPANHA", 'data_inicial' as "MES_REFERENCIA", 'OSTON' as "FORNECEDOR", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' when c.id = 2 then '09 Informativo' when c.id = 63 then '07 Pagamento de fatura' else '' end "MACRO_CATEGORIA", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03 Pré > Controle' when c.id = 2 then '09.01 Regulatório / Obrigatório TIM' when c.id = 63 then '07.01 Meio de pagamento (ex-Parcerias)' else '' end "CATEGORIA", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03.02 Pré > Controle : SEM aparelho' when c.id = 2 then '09.01.02 Normativo : COM relação direta' when c.id = 63 then '07.01.05 Pagamento por outros meios (ex-Parcerias)' else '' end "SUB_CATEGORIA", count(se.id) as "VOLUME_PUBLICO", r.type as "TIPO_MENSAGEM" from production.sent_messages as se inner join production.rules r ON se.rule_id = r.id inner join production.campaigns c ON r.campaign_id = c.id where (se.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59
#    Query 2: select '1002' as "CODIGO_CAMPANHA", c.name as "NOME_CAMPANHA", 'data_inicial' as "MES_REFERENCIA", 'OSTON' as "FORNECEDOR", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as "MACRO_CATEGORIA", '02.03 Pré > Controle' as "CATEGORIA", '02.03.02 Pré > Controle : SEM aparelho' as "SUB_CATEGORIA", count(mo.id) as "VOLUME_PUBLICO", 'SMS' as "TIPO_MENSAGEM" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59
#    Query 3: select c.id as "CODIGO_CAMPANHA", c.name as "NOME_CAMPANHA", 'data_inicial' as "MES_REFERENCIA", 'OSTON' as "FORNECEDOR", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' when c.id = 2 then '09 Informativo' when c.id = 63 then '07 Pagamento de fatura' else '' end "MACRO_CATEGORIA", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03 Pré > Controle' when c.id = 2 then '09.01 Regulatório / Obrigatório TIM' when c.id = 63 then '07.01 Meio de pagamento (ex-Parcerias)' else '' end "CATEGORIA", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03.02 Pré > Controle : SEM aparelho' when c.id = 2 then '09.01.02 Normativo : COM relação direta' when c.id = 63 then '07.01.05 Pagamento por outros meios (ex-Parcerias)' else '' end "SUB_CATEGORIA", count(se.id) as "VOLUME_PUBLICO", r.type as "TIPO_MENSAGEM" from production.sent_messages as se inner join production.rules r ON se.rule_id = r.id inner join production.campaigns c ON r.campaign_id = c.id where (se.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59
#    Query 4: select '1002' as "CODIGO_CAMPANHA", c.name as "NOME_CAMPANHA", 'data_inicial' as "MES_REFERENCIA", 'OSTON' as "FORNECEDOR", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as "MACRO_CATEGORIA", '02.03 Pré > Controle' as "CATEGORIA", '02.03.02 Pré > Controle : SEM aparelho' as "SUB_CATEGORIA", count(mo.id) as "VOLUME_PUBLICO", 'SMS' as "TIPO_MENSAGEM" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59
#
# 📄 Arquivo: bases_diarias_sms_por_campanha_completa_flash.py
#    Query 1: select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end "CODIGO_CAMPANHA", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end "NOME_CAMPANHA", 'data_inicial' as "MES_REFERENCIA", 'OSTON' as "FORNECEDOR", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as "MACRO_CATEGORIA", '02.03 Pré > Controle' as "CATEGORIA", '02.03.02 Pré > Controle : SEM aparelho' as "SUB_CATEGORIA", count(mo.id) as "VOLUME_PUBLICO", 'SMS' as "TIPO_MENSAGEM" from message_outbound as mo where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59
#    Query 2: select case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end "CODIGO_CAMPANHA", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end "NOME_CAMPANHA", 'data_inicial' as "MES_REFERENCIA", 'OSTON' as "FORNECEDOR", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as "MACRO_CATEGORIA", '02.03 Pré > Controle' as "CATEGORIA", '02.03.02 Pré > Controle : SEM aparelho' as "SUB_CATEGORIA", count(mo.id) as "VOLUME_PUBLICO", 'SMS' as "TIPO_MENSAGEM" from message_outbound as mo where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59

# %%
def extract_queries_for_llm(shared_outputs, results):
    """Prepara dados para enviar para LLM"""
    
    for output, files in shared_outputs.items():
        print(f"\n{'='*50}")
        print(f"CONSOLIDAÇÃO PARA: {output}")
        print('='*50)
        
        all_queries = []
        
        for file in files:
            queries = results[file].get('queries', [])
            select_queries = [q.replace('""', '').strip() 
                            for q in queries if 'SELECT' in q.upper()]
            
            for query in select_queries:
                all_queries.append(f"-- De {file}\n{query}")
        
        # Dados para LLM
        llm_input = {
            'target_table': output,
            'queries': all_queries,
            'task': 'Transformar essas queries em um UNION ALL otimizado'
        }
        
        print("📤 Para LLM:")
        print(json.dumps(llm_input, indent=2, ensure_ascii=False))

# %%
qury = extract_queries_for_llm(shared_outputs, results)
# Out:
# ==================================================
# CONSOLIDAÇÃO PARA: sms_por_campanha
# ==================================================
# 📤 Para LLM:
# {
#   "target_table": "sms_por_campanha",
#   "queries": [
#     "-- De bases_diarias_sms_por_campanha.py\nselect c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' when c.id = 2 then '09 Informativo' when c.id = 63 then '07 Pagamento de fatura' else '' end \"MACRO_CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03 Pré > Controle' when c.id = 2 then '09.01 Regulatório / Obrigatório TIM' when c.id = 63 then '07.01 Meio de pagamento (ex-Parcerias)' else '' end \"CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03.02 Pré > Controle : SEM aparelho' when c.id = 2 then '09.01.02 Normativo : COM relação direta' when c.id = 63 then '07.01.05 Pagamento por outros meios (ex-Parcerias)' else '' end \"SUB_CATEGORIA\", count(se.id) as \"VOLUME_PUBLICO\", r.type as \"TIPO_MENSAGEM\" from production.sent_messages as se inner join production.rules r ON se.rule_id = r.id inner join production.campaigns c ON r.campaign_id = c.id where (se.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#     "-- De bases_diarias_sms_por_campanha.py\nselect '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#     "-- De bases_diarias_sms_por_campanha.py\nselect c.id as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' when c.id = 2 then '09 Informativo' when c.id = 63 then '07 Pagamento de fatura' else '' end \"MACRO_CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03 Pré > Controle' when c.id = 2 then '09.01 Regulatório / Obrigatório TIM' when c.id = 63 then '07.01 Meio de pagamento (ex-Parcerias)' else '' end \"CATEGORIA\", case when c.id in (1, 3, 7, 27, 62, 149, 150, 151) then '02.03.02 Pré > Controle : SEM aparelho' when c.id = 2 then '09.01.02 Normativo : COM relação direta' when c.id = 63 then '07.01.05 Pagamento por outros meios (ex-Parcerias)' else '' end \"SUB_CATEGORIA\", count(se.id) as \"VOLUME_PUBLICO\", r.type as \"TIPO_MENSAGEM\" from production.sent_messages as se inner join production.rules r ON se.rule_id = r.id inner join production.campaigns c ON r.campaign_id = c.id where (se.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#     "-- De bases_diarias_sms_por_campanha.py\nselect '1002' as \"CODIGO_CAMPANHA\", c.name as \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo inner join campaigns as c on mo.campaign_id = c.id where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#     "-- De bases_diarias_sms_por_campanha_completa_flash.py\nselect case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59",
#     "-- De bases_diarias_sms_por_campanha_completa_flash.py\nselect case when mo.campaign_id = 2 then '1002' when mo.campaign_id = 7 then '1007' when mo.campaign_id = 8 then '1008' when mo.campaign_id = 9 then '1009' when mo.campaign_id = 10 then '1010' when mo.campaign_id = 12 then '1012' when mo.campaign_id = 13 then '1013' when mo.campaign_id = 5 then '1005' when mo.campaign_id = 6 then '1006' when mo.campaign_id = 11 then '1011' when mo.campaign_id = 14 then '1014' else '' end \"CODIGO_CAMPANHA\", case when mo.campaign_id = 2 then 'URA' when mo.campaign_id = 7 then 'Base Oston - H24' when mo.campaign_id = 8 then 'Base Oston - H48' when mo.campaign_id = 9 then 'Base Oston - H96' when mo.campaign_id = 10 then 'Base Oston - 144' when mo.campaign_id = 12 then 'Teste BOT - Com botão' when mo.campaign_id = 13 then 'Teste BOT - Sem botão' when mo.campaign_id = 5 then 'Base Oston - H0' when mo.campaign_id = 6 then 'DisplayText' when mo.campaign_id = 11 then 'Teste - Display Text' when mo.campaign_id = 14 then 'Pedidos com sucesso' else '' end \"NOME_CAMPANHA\", 'data_inicial' as \"MES_REFERENCIA\", 'OSTON' as \"FORNECEDOR\", '02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia' as \"MACRO_CATEGORIA\", '02.03 Pré > Controle' as \"CATEGORIA\", '02.03.02 Pré > Controle : SEM aparelho' as \"SUB_CATEGORIA\", count(mo.id) as \"VOLUME_PUBLICO\", 'SMS' as \"TIPO_MENSAGEM\" from message_outbound as mo where (mo.sent_at between 'data_inicial 00:00:00' and 'data 23:59:59"
#   ],
#   "task": "Transformar essas queries em um UNION ALL otimizado"
# }

# %%
import google.generativeai as genai
from pydantic import BaseModel, ValidationError
import json

class CampanhaSMS(BaseModel):
    CODIGO_CAMPANHA: str
    NOME_CAMPANHA: str
    MES_REFERENCIA: str
    FORNECEDOR: str
    MACRO_CATEGORIA: str
    CATEGORIA: str
    SUB_CATEGORIA: str
    VOLUME_PUBLICO: int
    TIPO_MENSAGEM: str

client = genai.configure(api_key="AIzaSyAx6iH1WuCJsb50_LhOahBr2OQnk3TqIq4") # Replace with your actual API key
model = genai.GenerativeModel('gemini-2.0-flash')


response = model.generate_content(
    contents=query,
    generation_config={
        "response_mime_type": "application/json" # This might be the correct parameter name if supported
    }
)

try:
    # Assuming the model returns a JSON string
    campaigns_data = json.loads(response.text)
    validated_campaigns = [CampanhaSMS(**campaign) for campaign in campaigns_data]
    for campaign in validated_campaigns:
        print(campaign.model_dump_json(indent=2))
except (json.JSONDecodeError, ValidationError) as e:
    print(f"Error parsing or validating response: {e}")
    print("Raw response text:", response.text)
# Out:
# Error parsing or validating response: 1 validation error for CampanhaSMS
# VOLUME_PUBLICO
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='COUNT(mo.id)', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/int_parsing
# Raw response text: [
#   {
#     "CODIGO_CAMPANHA": "CASE WHEN mo.campaign_id = 2 THEN '1002' WHEN mo.campaign_id = 7 THEN '1007' WHEN mo.campaign_id = 8 THEN '1008' WHEN mo.campaign_id = 9 THEN '1009' WHEN mo.campaign_id = 10 THEN '1010' WHEN mo.campaign_id = 12 THEN '1012' WHEN mo.campaign_id = 13 THEN '1013' WHEN mo.campaign_id = 5 THEN '1005' WHEN mo.campaign_id = 6 THEN '1006' WHEN mo.campaign_id = 11 THEN '1011' WHEN mo.campaign_id = 14 THEN '1014' ELSE '' END",
#     "NOME_CAMPANHA": "CASE WHEN mo.campaign_id = 2 THEN 'URA' WHEN mo.campaign_id = 7 THEN 'Base Oston - H24' WHEN mo.campaign_id = 8 THEN 'Base Oston - H48' WHEN mo.campaign_id = 9 THEN 'Base Oston - H96' WHEN mo.campaign_id = 10 THEN 'Base Oston - 144' WHEN mo.campaign_id = 12 THEN 'Teste BOT - Com botão' WHEN mo.campaign_id = 13 THEN 'Teste BOT - Sem botão' WHEN mo.campaign_id = 5 THEN 'Base Oston - H0' WHEN mo.campaign_id = 6 THEN 'DisplayText' WHEN mo.campaign_id = 11 THEN 'Teste - Display Text' WHEN mo.campaign_id = 14 THEN 'Pedidos com sucesso' ELSE '' END",
#     "MES_REFERENCIA": "data_inicial",
#     "FORNECEDOR": "OSTON",
#     "MACRO_CATEGORIA": "02 Estímulo a Upgrade de Produto / Plano / Oferta / Tecnologia",
#     "CATEGORIA": "02.03 Pré > Controle",
#     "SUB_CATEGORIA": "02.03.02 Pré > Controle : SEM aparelho",
#     "VOLUME_PUBLICO": "COUNT(mo.id)",
#     "TIPO_MENSAGEM": "SMS"
#   }
# ]
